# %%
dataset_path = "/Users/ramith/Datasets/classification-of-heart-sound-recordings-the-physionet-computing-in-cardiology-challenge-2016-1.0.0"

# %%
import matplotlib.pyplot as plt
import numpy as np
import wave
import sys
import os
import random
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 
import wfdb
from pydub import AudioSegment
import wfdb_custom
from wfdb import processing
import IPython
import scipy.fftpack
from scipy.signal import blackman
import pywt

# %%
import scaleogram as scg

# %%
files = os.listdir(dataset_path + '/training-a/')

# %%
wav_files  = sorted([file for file in files if '.wav' in file])

# %%
def HS_plot(x,s=0,e=-1,db=20):
    file = x
    path = x
    
    if(type(x)==int):
        file = wav_files[x]
        path = dataset_path + '/training-a/' +  file 
        spf  = wave.open(path, "r")

        meta_data = dataset_path + '/training-a/' + file[:-3] + 'hea'

        with open(meta_data) as f:
            content = f.readlines()
    else:
        spf  = wave.open(path , "r")
        content = ['N/A']
    
    print()
    # Extract Raw Audio from Wav File
    signal = spf.readframes(-1)
    signal = np.frombuffer(signal, dtype='int16')

    # If Stereo
    if spf.getnchannels() == 2:
        print("Just mono files")
        sys.exit(0)
    
    x = [0, 1, 2]
    y = [0, 1, 2]

    r = random.random()
    b = random.random()
    g = random.random()
    color = (r, g, b)

    plt.figure(figsize=(20,4))
    plt.title("HS Sound - " + file + ' => '+ content[-1])
    
    ee = e

    if e==-1:
        ee = len(signal) - 1
    x = [i for i in range(s,ee)]
    
    plt.plot(x,signal[s:e],c=color)
    plt.show()

    song = AudioSegment.from_wav(path) + db
    song = song[s/2:e/2]
    
    path = "edited/" + "temp.mp3"
    song.export(path , "mp3")
    
    return song,signal

# %%
[audio,l] = HS_plot(302)

print(len(l))
new = audio.high_pass_filter(200)

path = "edited/" + "temp.wav"
new.export(path , "wav")

print("Low Pass filtered")
IPython.display.Audio(path)
# Out:
# 71611
# Low Pass filtered
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
audio
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %%
[x,s] = HS_plot('edited/temp.wav',0,40500)

# %%
def plot_pcg_ecg(x,s=0,e=-1):
    rec = wav_files[x][:-4]

    record = wfdb.rdrecord(dataset_path + '/training-a/'+rec) 
    pcg_p = wfdb.processing.find_local_peaks(record.p_signal[:,0],1000) 
    ecg_p = wfdb.processing.find_local_peaks(record.p_signal[:,1],300)
    
    #pcg_p = wfdb.processing.find__peaks(record.p_signal[:,0])[0] #0 for hard peaks 
  
    
    peaks = [pcg_p , ecg_p]
    
    wfdb_custom.plot_wfdb(s,e,peaks,record=record, title='Record ' + rec + ' from PhysioNet Challenge 2016' + ' => ' + record.__dict__['comments'][0],figsize=(20,10), time_units = 'samples',ecg_grids=[1]) 
    display(record.__dict__)

# %%
plot_pcg_ecg(280,0,30000)
# Out:
# {'record_name': 'a0281',
#  'n_sig': 2,
#  'fs': 2000,
#  'counter_freq': None,
#  'base_counter': None,
#  'sig_len': 57148,
#  'base_time': None,
#  'base_date': None,
#  'comments': ['Abnormal'],
#  'sig_name': ['PCG', 'ECG'],
#  'p_signal': array([[ 2.5900e+02, -1.0000e-03],
#         [ 5.6300e+02, -1.0000e-03],
#         [ 5.4500e+02, -2.0000e-03],
#         ...,
#         [-1.0000e+00,  1.4826e+01],
#         [-1.0000e+00,  1.6369e+01],
#         [ 0.0000e+00,  1.7843e+01]]),
#  'd_signal': None,
#  'e_p_signal': None,
#  'e_d_signal': None,
#  'file_name': ['a0281.wav', 'a0281.dat'],
#  'fmt': ['16', '16'],
#  'samps_per_frame': [1, 1],
#  'skew': [None, None],
#  'byte_offset': [44, None],
#  'adc_gain': [1.0, 1000.0],
#  'baseline': [0, 0],
#  'units': ['mV', 'mV'],
#  'adc_res': [16, 16],
#  'adc_zero': [0, 0],
#  'init_value': [0, -1],
#  'checksum': [0, 12176],
#  'block_size': [0, 0]}

# %%
def increase_volume(x,db=20):
    song = AudioSegment.from_wav(dataset_path + '/training-a/'+wav_files[0])
    song = song + db
    
    path = "edited/" + wav_files[0]
    song.export("edited/" + wav_files[0] , "wav")

    return IPython.display.Audio(path)

# %%
increase_volume(0)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plot_pcg_ecg(80,100,3000)
# Out:
# {'record_name': 'a0081',
#  'n_sig': 2,
#  'fs': 2000,
#  'counter_freq': None,
#  'base_counter': None,
#  'sig_len': 71332,
#  'base_time': None,
#  'base_date': None,
#  'comments': ['Normal'],
#  'sig_name': ['PCG', 'ECG'],
#  'p_signal': array([[-2.000e+01,  0.000e+00],
#         [-7.100e+01, -3.000e-03],
#         [-4.300e+01, -7.000e-03],
#         ...,
#         [ 1.238e+03, -1.120e-01],
#         [ 1.966e+03, -1.120e-01],
#         [ 2.502e+03, -1.110e-01]]),
#  'd_signal': None,
#  'e_p_signal': None,
#  'e_d_signal': None,
#  'file_name': ['a0081.wav', 'a0081.dat'],
#  'fmt': ['16', '16'],
#  'samps_per_frame': [1, 1],
#  'skew': [None, None],
#  'byte_offset': [44, None],
#  'adc_gain': [1.0, 1000.0],
#  'baseline': [0, 0],
#  'units': ['mV', 'mV'],
#  'adc_res': [16, 16],
#  'adc_zero': [0, 0],
#  'init_value': [0, 0],
#  'checksum': [0, -12715],
#  'block_size': [0, 0]}

# %%
dt = 1/2000  # 2000 Hz sampling
frequencies = pywt.scale2frequency('cmor1.5-1.0', [2000,200]) / dt
frequencies
# Out:
# array([ 1., 10.])

# %%
#wavlist = pywt.wavelist(kind='continuous')
#wavlist

# %%
# Obtaining CWT and Plotting using scaleogram library
scg.set_default_wavelet('cmor1.5-1.0')
# Useful bandwidth of ECG = (0.5,100)Hz
# The higher the scale applied to the transform, the wavelet becomes more sensitive to low frequencies of
#    the given signal
# Increased scale thus contributes to the smoothening of the X axis
scales = np.arange(2, 60)

# %%
def plot_wavelet(ecg,fs,scales,xlim,title):
    ''' Computing CWT and Plotting Scalogram '''

    
    t = np.array(range(len(ecg)-1))/fs
    cwt = scg.CWT(t, ecg,scales)
    scg.cws(cwt, figsize = (10,5),xlim = xlim, yaxis='frequency',yscale = 'log',title = title,cscale='linear',cbar=None)

# %%
plot_wavelet(a[:1000],2000,scales,(0,71332),'tk')

# %%
rec = wav_files[80][:-4]
record = wfdb.rdrecord(dataset_path + '/training-a/'+rec) 
a = record.p_signal[:,0]

scales = np.arange(1, 70)
ax2 = scg.cws(a[100:10000], scales=scales, figsize=(9,5),yaxis='frequency',yscale = 'log',cscale='linear')

# %%
scales

# %%
plt.plot(a[100:10000])

# %%
len(record.p_signal[:,0])
# Out:
# 71332
